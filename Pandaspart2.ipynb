# %%
import pandas as pd

# %%
df=pd.read_csv('car_data.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
df[(df['Make']=='Toyota')&(df['Odometer (KM)']<70000)]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df['Odometer (Mile)']=df['Odometer (KM)'] /1.6
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
df.drop('Odometer (Mile)',axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.drop('Odometer (Mile)',axis=1,inplace=True)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df['Odometer (Mile)']=df['Odometer (KM)'].apply(lambda x:x/1.6)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
def currency(x):
  if '$' in x:
    return 'USD'
  else:
    return 'unknown'
df['Currency']=df['Price'].apply(currency)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
#df['Currency'] = df['Price'].apply(lambda x: 'USD' if '$' in x else 'unknown')

# %%
df['Price']=df['Price'].str.replace('[/$/,/.]','',regex=True)
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   400000        93776.875      USD
# 1   Honda    Red          87899      4   500000        54936.875      USD
# 2  Toyota   Blue          32549      3   700000        20343.125      USD
# 3     BMW  Black          11179      5  2200000         6986.875      USD
# 4  Nissan  White         213095      4   350000       133184.375      USD
# 5  Toyota  Green          99213      4   450000        62008.125      USD
# 6   Honda   Blue          45698      4   750000        28561.250      USD
# 7   Honda   Blue          54738      4   700000        34211.250      USD
# 8  Toyota  White          60000      4   625000        37500.000      USD
# 9  Nissan  White          31600      4   970000        19750.000      USD

# %%
df['Price']=df['Price'].astype(int)
df.dtypes
# Out:
# Make                object
# Colour              object
# Odometer (KM)        int64
# Doors                int64
# Price                int64
# Odometer (Mile)    float64
# Currency            object
# dtype: object

# %%
df['Price']=df['Price']/100
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD
# 5  Toyota  Green          99213      4   4500.0        62008.125      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 8  Toyota  White          60000      4   6250.0        37500.000      USD
# 9  Nissan  White          31600      4   9700.0        19750.000      USD

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875      USD
# 1   Honda    Red          87899      4   5000.0        54936.875      USD
# 2  Toyota   Blue          32549      3   7000.0        20343.125      USD
# 3     BMW  Black          11179      5  22000.0         6986.875      USD
# 4  Nissan  White         213095      4   3500.0       133184.375      USD
# 5  Toyota  Green          99213      4   4500.0        62008.125      USD
# 6   Honda   Blue          45698      4   7500.0        28561.250      USD
# 7   Honda   Blue          54738      4   7000.0        34211.250      USD
# 8  Toyota  White          60000      4   6250.0        37500.000      USD
# 9  Nissan  White          31600      4   9700.0        19750.000      USD

# %%
df['Price'].plot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors         Price  Odometer (Mile)
# count      10.000000  10.000000     10.000000        10.000000
# mean    78601.400000   4.000000   7645.000000     49125.875000
# std     61983.471735   0.471405   5379.407753     38739.669834
# min     11179.000000   3.000000   3500.000000      6986.875000
# 25%     35836.250000   4.000000   4625.000000     22397.656250
# 50%     57369.000000   4.000000   6625.000000     35855.625000
# 75%     96384.500000   4.000000   7375.000000     60240.312500
# max    213095.000000   5.000000  22000.000000    133184.375000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Make             10 non-null     object
#  1   Colour           10 non-null     object
#  2   Odometer (KM)    10 non-null     int64
#  3   Doors            10 non-null     int64
#  4   Price            10 non-null     float64
#  5   Odometer (Mile)  10 non-null     float64
#  6   Currency         10 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 692.0+ bytes

# %%
df.drop('Odometer (KM)',inplace=True,axis=1)

# %%
df
# Out:
#      Make Colour  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White      4   4000.0        93776.875      USD
# 1   Honda    Red      4   5000.0        54936.875      USD
# 2  Toyota   Blue      3   7000.0        20343.125      USD
# 3     BMW  Black      5  22000.0         6986.875      USD
# 4  Nissan  White      4   3500.0       133184.375      USD
# 5  Toyota  Green      4   4500.0        62008.125      USD
# 6   Honda   Blue      4   7500.0        28561.250      USD
# 7   Honda   Blue      4   7000.0        34211.250      USD
# 8  Toyota  White      4   6250.0        37500.000      USD
# 9  Nissan  White      4   9700.0        19750.000      USD

# %%
df['Price'].mean()
# Out:
# np.float64(7645.0)

# %%
df.groupby(['Make','Colour']).mean(numeric_only=True)
# Out:
#                Doors    Price  Odometer (Mile)
# Make   Colour
# BMW    Black     5.0  22000.0        6986.8750
# Honda  Blue      4.0   7250.0       31386.2500
#        Red       4.0   5000.0       54936.8750
# Nissan White     4.0   6600.0       76467.1875
# Toyota Blue      3.0   7000.0       20343.1250
#        Green     4.0   4500.0       62008.1250
#        White     4.0   5125.0       65638.4375

# %%
df_copy=df.copy()
df_copy
# Out:
#      Make Colour  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White      4   4000.0        93776.875      USD
# 1   Honda    Red      4   5000.0        54936.875      USD
# 2  Toyota   Blue      3   7000.0        20343.125      USD
# 3     BMW  Black      5  22000.0         6986.875      USD
# 4  Nissan  White      4   3500.0       133184.375      USD
# 5  Toyota  Green      4   4500.0        62008.125      USD
# 6   Honda   Blue      4   7500.0        28561.250      USD
# 7   Honda   Blue      4   7000.0        34211.250      USD
# 8  Toyota  White      4   6250.0        37500.000      USD
# 9  Nissan  White      4   9700.0        19750.000      USD

# %%
#df = pd.read_excel("data.xlsx", sheet_name="Sheet1")
#df = pd.read_json("data.json")

# %%
car_sales_missing=pd.read_csv("/content/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isna()
# Out:
#     Make  Colour  Odometer  Doors  Price
# 0  False   False     False  False  False
# 1  False   False     False  False  False
# 2  False   False      True  False  False
# 3  False   False     False  False  False
# 4  False   False     False  False  False
# 5  False   False      True  False  False
# 6  False    True      True  False  False
# 7  False   False      True  False   True
# 8  False   False     False   True   True
# 9   True   False     False  False  False

# %%
car_sales_missing.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_sales_missing.dropna(subset=['Price'],inplace=True)  #Bos setirleri silsin deye

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer']=car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   98763.2    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   98763.2    4.0   $4,500
# 6   Honda    NaN   98763.2    4.0   $7,500
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].median())

# %%
car_sales_missing['Colour'] = car_sales_missing['Colour'].fillna(
    car_sales_missing['Colour'].mode()[0]
)

# %%
car_sales_missing['Make'] = car_sales_missing['Make'].fillna(
    car_sales_missing['Make'].mode()[0]
)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   98763.2    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   98763.2    4.0   $4,500
# 6   Honda  White   98763.2    4.0   $7,500
# 9  Toyota  White   31600.0    4.0   $9,700

# %%
# for col in ['Make', 'Colour']:
#     car_sales_missing[col] = car_sales_missing[col].fillna(
#         car_sales_missing[col].mode()[0]
#     )

# %%
table_a=pd.DataFrame({'id':['a1','a2','a3','a4'],'Value':['A','B','C','AA']})
table_b=pd.DataFrame({'id':['a1','a2','a3','a5'],'Value':['D','E','F','BB']})
pd.merge(table_a,table_b,on='id')  #inner join
# Out:
#    id Value_x Value_y
# 0  a1       A       D
# 1  a2       B       E
# 2  a3       C       F

# %%
table_a=pd.DataFrame({'id1':['a1','a2','a3','a4'],'Value':['A','B','C','AA']})
table_b=pd.DataFrame({'id2':['a1','a2','a3','a5'],'Value':['D','E','F','BB']})
pd.merge(table_a,table_b,left_on='id1',right_on='id2',how='right')  # sutun adlari ferqlidirse
# Out:
#    id1 Value_x id2 Value_y
# 0   a1       A  a1       D
# 1   a2       B  a2       E
# 2   a3       C  a3       F
# 3  NaN     NaN  a5      BB

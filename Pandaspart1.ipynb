# %%
# Series = tək sütunlu məlumatdır.
# Excel-də 1 dənə sütun kimi düşün.

# Tək ölçülüdür (1D)

# Hər elementin index-i olur

# Yalnız bir “column” kimi işləyir

# %%
import pandas as pd
masinlar=pd.Series(["BMW","TESLA","TOYOTA"])
masinlar
# Out:
# 0       BMW
# 1     TESLA
# 2    TOYOTA
# dtype: object

# %%
masinlar[2]
# Out:
# 'TOYOTA'

# %%
masinlar.values
# Out:
# array(['BMW', 'TESLA', 'TOYOTA'], dtype=object)

# %%
masinlar=pd.Series(["BMW","TESLA","TOYOTA"],index=["a","b","c"])
masinlar
# Out:
# a       BMW
# b     TESLA
# c    TOYOTA
# dtype: object

# %%
masinlar["a"]
# Out:
# 'BMW'

# %%
masinlar.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
#list,tuple,dic seriese cevire bilirik

# %%
bal={"Ferman":90,"Nazli":67,"Sebnem":87}
sr=pd.Series(bal)
sr
# Out:
# Ferman    90
# Nazli     67
# Sebnem    87
# dtype: int64

# %%
sr["Nazli"]
# Out:
# np.int64(67)

# %%
sr[sr>70]
# Out:
# Ferman    90
# Sebnem    87
# dtype: int64

# %%
sr<70
# Out:
# Ferman    False
# Nazli      True
# Sebnem    False
# dtype: bool

# %%
sr["Nazli"]=70
sr
# Out:
# Ferman    90
# Nazli     70
# Sebnem    87
# dtype: int64

# %%
sr[sr<80]=85
sr
# Out:
# Ferman    90
# Nazli     85
# Sebnem    87
# dtype: int64

# %%
"Nazli" in sr
# Out:
# True

# %%
#riyazi hesablamalar ede bilerik
sr/10
# Out:
# Ferman    9.0
# Nazli     8.5
# Sebnem    8.7
# dtype: float64

# %%
sr.isnull()
# Out:
# Ferman    False
# Nazli     False
# Sebnem    False
# dtype: bool

# %%
# DateFrame
# DataFrame = çox sütunlu cədvəldir.
# Excel-də bütöv bir sheet kimi düşün.

# İki ölçülüdür (2D)

# Birdən çox column olur

# Hər column içində əslində bir Series var

# %%
mar=pd.Series(['BMW','TOYOTA','TESLA'])
mar
# Out:
# 0       BMW
# 1    TOYOTA
# 2     TESLA
# dtype: object

# %%
reng=pd.Series(['Qara','Sari','Qirmizi'])
reng
# Out:
# 0       Qara
# 1       Sari
# 2    Qirmizi
# dtype: object

# %%
masin=pd.DataFrame({'Marka':mar,'Reng':reng})
masin
# Out:
#     Marka     Reng
# 0     BMW     Qara
# 1  TOYOTA     Sari
# 2   TESLA  Qirmizi

# %%
uni={"telebe":["Fikret","Musa"],
      "bal":[67,98]}
df=pd.DataFrame(uni)
df
# Out:
#    telebe  bal
# 0  Fikret   67
# 1    Musa   98

# %%
data={"Ad":["Dunya","Camal","Fikret","Qasim","Sefa","Tofiq"],
      "Bal":[76,56,78,89,65,73],
      "Cins":["Q","K","K","K","Q","K"]}
df=pd.DataFrame(data)
df
# Out:
#        Ad  Bal Cins
# 0   Dunya   76    Q
# 1   Camal   56    K
# 2  Fikret   78    K
# 3   Qasim   89    K
# 4    Sefa   65    Q
# 5   Tofiq   73    K

# %%
df.head()
# Out:
#        Ad  Bal Cins
# 0   Dunya   76    Q
# 1   Camal   56    K
# 2  Fikret   78    K
# 3   Qasim   89    K
# 4    Sefa   65    Q

# %%
df.tail()
# Out:
#        Ad  Bal Cins
# 1   Camal   56    K
# 2  Fikret   78    K
# 3   Qasim   89    K
# 4    Sefa   65    Q
# 5   Tofiq   73    K

# %%
df=pd.DataFrame(data,columns=["Ad","Bal","Cins","Yas"])
df
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q  NaN
# 1   Camal   56    K  NaN
# 2  Fikret   78    K  NaN
# 3   Qasim   89    K  NaN
# 4    Sefa   65    Q  NaN
# 5   Tofiq   73    K  NaN

# %%
df["Ad"]
# Out:
# 0     Dunya
# 1     Camal
# 2    Fikret
# 3     Qasim
# 4      Sefa
# 5     Tofiq
# Name: Ad, dtype: object

# %%
sutunlar=["Cins","Bal"]
df[sutunlar]
# Out:
#   Cins  Bal
# 0    Q   76
# 1    K   56
# 2    K   78
# 3    K   89
# 4    Q   65
# 5    K   73

# %%
df.Ad
# Out:
# 0     Dunya
# 1     Camal
# 2    Fikret
# 3     Qasim
# 4      Sefa
# 5     Tofiq
# Name: Ad, dtype: object

# %%
df.loc[[1,2]] #label ile secir(index)
# Out:
#        Ad  Bal Cins  Yas
# 1   Camal   56    K  NaN
# 2  Fikret   78    K  NaN

# %%
df["Yas"]=18
df
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q   18
# 1   Camal   56    K   18
# 2  Fikret   78    K   18
# 3   Qasim   89    K   18
# 4    Sefa   65    Q   18
# 5   Tofiq   73    K   18

# %%
deyerler=[18,17,20,23,19,20]
df["Yas"]=deyerler
df
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q   18
# 1   Camal   56    K   17
# 2  Fikret   78    K   20
# 3   Qasim   89    K   23
# 4    Sefa   65    Q   19
# 5   Tofiq   73    K   20

# %%
df["Imtkec"]=df["Bal"]>70
df
# Out:
#        Ad  Bal Cins  Yas  Imtkec
# 0   Dunya   76    Q   18    True
# 1   Camal   56    K   17   False
# 2  Fikret   78    K   20    True
# 3   Qasim   89    K   23    True
# 4    Sefa   65    Q   19   False
# 5   Tofiq   73    K   20    True

# %%
del df["Imtkec"]
df
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q   18
# 1   Camal   56    K   17
# 2  Fikret   78    K   20
# 3   Qasim   89    K   23
# 4    Sefa   65    Q   19
# 5   Tofiq   73    K   20

# %%
df.T
# Out:
#           0      1       2      3     4      5
# Ad    Dunya  Camal  Fikret  Qasim  Sefa  Tofiq
# Bal      76     56      78     89    65     73
# Cins      Q      K       K      K     Q      K
# Yas      18     17      20     23    19     20

# %%
df[0:3]
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q   18
# 1   Camal   56    K   17
# 2  Fikret   78    K   20

# %%
df
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q   18
# 1   Camal   56    K   17
# 2  Fikret   78    K   20
# 3   Qasim   89    K   23
# 4    Sefa   65    Q   19
# 5   Tofiq   73    K   20

# %%
df.iloc[1] #Series qaytarir indexi 1 olan setir
# Out:
# Ad      Camal
# Bal        56
# Cins        K
# Yas        17
# Name: 1, dtype: object

# %%
df.iloc[1,[2,3]] #1-ci setir,2,3cu sutun
# Out:
# Cins     K
# Yas     17
# Name: 1, dtype: object

# %%
df
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q   18
# 1   Camal   56    K   17
# 2  Fikret   78    K   20
# 3   Qasim   89    K   23
# 4    Sefa   65    Q   19
# 5   Tofiq   73    K   20

# %%
df.loc[1,["Bal"]]
# Out:
# Bal    56
# Name: 1, dtype: object

# %%
df
# Out:
#        Ad  Bal Cins  Yas
# 0   Dunya   76    Q   18
# 1   Camal   56    K   17
# 2  Fikret   78    K   20
# 3   Qasim   89    K   23
# 4    Sefa   65    Q   19
# 5   Tofiq   73    K   20

# %%
df=df.drop("Bal",axis=1)  #axis=1 sutunlar,axis=0 setirler
df
# Out:
#        Ad Cins  Yas
# 0   Dunya    Q   18
# 1   Camal    K   17
# 2  Fikret    K   20
# 3   Qasim    K   23
# 4    Sefa    Q   19
# 5   Tofiq    K   20

# %%
df.drop(2,axis=0)
# Out:
#       Ad Cins  Yas
# 0  Dunya    Q   18
# 1  Camal    K   17
# 3  Qasim    K   23
# 4   Sefa    Q   19
# 5  Tofiq    K   20

# %%
df.sort_index()
# Out:
#        Ad Cins  Yas
# 0   Dunya    Q   18
# 1   Camal    K   17
# 2  Fikret    K   20
# 3   Qasim    K   23
# 4    Sefa    Q   19
# 5   Tofiq    K   20

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#    Yas Cins      Ad
# 0   18    Q   Dunya
# 1   17    K   Camal
# 2   20    K  Fikret
# 3   23    K   Qasim
# 4   19    Q    Sefa
# 5   20    K   Tofiq

# %%
df.sort_values("Yas")
# Out:
#        Ad Cins  Yas
# 1   Camal    K   17
# 0   Dunya    Q   18
# 4    Sefa    Q   19
# 2  Fikret    K   20
# 5   Tofiq    K   20
# 3   Qasim    K   23

# %%
df.sort_values(["Yas","Ad"])
# Out:
#        Ad Cins  Yas
# 1   Camal    K   17
# 0   Dunya    Q   18
# 4    Sefa    Q   19
# 2  Fikret    K   20
# 5   Tofiq    K   20
# 3   Qasim    K   23
